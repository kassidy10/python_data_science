# %%
import pandas as pd

# %%
df = pd.read_csv('Data.csv',index_col = 'Respondent')
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
pd.set_option('display.max_columns', 61)

# %%
schema_df = pd.read_csv('dataSchema.csv', index_col='Column')
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.sort_index()
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
import pandas as pd

# %%
person = {
    'first' : 'corey',
    'last'  : 'Schafer',
    'email' : 'coreyschafer@gmail.com'
}

# %%
people = {
    'first': [ 'corey', 'jane', 'john'],
    'last' : ['schafer', 'doe', 'dan'],
    'email' : ['coreyschafer@gmail.com','victoriheanachoc@gmail.com','johndoe@gmai.com']
}

# %%
people['email']
# Out:
# ['coreyschafer@gmail.com', 'victoriheanachoc@gmail.com', 'johndoe@gmai.com']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                       email
# 0  corey  schafer      coreyschafer@gmail.com
# 1   jane      doe  victoriheanachoc@gmail.com
# 2   john      dan            johndoe@gmai.com

# %%
df[['last','email']]
# Out:
#       last                       email
# 0  schafer      coreyschafer@gmail.com
# 1      doe  victoriheanachoc@gmail.com
# 2      dan            johndoe@gmai.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#to target rows, we use 'loc' and 'iloc'
#iloc helps us access rows by integer location
df.iloc[[0,2],2]
# Out:
# 0    coreyschafer@gmail.com
# 2          johndoe@gmai.com
# Name: email, dtype: object

# %%
df.loc[[1,2], ['last','email']]
# Out:
#   last                       email
# 1  doe  victoriheanachoc@gmail.com
# 2  dan            johndoe@gmai.com

# %%
df.set_index('email',inplace = True)

# %%
df
# Out:
#                             first     last
# email
# coreyschafer@gmail.com      corey  schafer
# victoriheanachoc@gmail.com   jane      doe
# johndoe@gmai.com             john      dan

# %%
df.index
# Out:
# Index(['coreyschafer@gmail.com', 'victoriheanachoc@gmail.com',
#        'johndoe@gmai.com'],
#       dtype='object', name='email')

# %%
df.loc['victoriheanachoc@gmail.com']
# Out:
# first    jane
# last      doe
# Name: victoriheanachoc@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                         email  first     last
# 0      coreyschafer@gmail.com  corey  schafer
# 1  victoriheanachoc@gmail.com   jane      doe
# 2            johndoe@gmai.com   john      dan

# %%
df.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
df.columns = ['email','first_name','last_name']

# %%
df
# Out:
#                         email first_name last_name
# 0      coreyschafer@gmail.com      corey   schafer
# 1  victoriheanachoc@gmail.com       jane       doe
# 2            johndoe@gmai.com       john       dan

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#                         email first_name last_name
# 0      coreyschafer@gmail.com      corey   schafer
# 1  victoriheanachoc@gmail.com       jane       doe
# 2            johndoe@gmai.com       john       dan

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#                         email first_name last_name
# 0      coreyschafer@gmail.com      corey   schafer
# 1  victoriheanachoc@gmail.com       jane       doe
# 2            johndoe@gmai.com       john       dan

# %%
df.rename(columns={'first_name' : 'first', 'last_name' : 'last'}, inplace = True)

# %%
df
# Out:
#                         email  first     last
# 0      coreyschafer@gmail.com  corey  schafer
# 1  victoriheanachoc@gmail.com   jane      doe
# 2            johndoe@gmai.com   john      dan

# %%
df.loc[2]
# Out:
# email    johndoe@gmai.com
# first                john
# last                  dan
# Name: 2, dtype: object

# %%
df.loc[2] = ['johnsmith@gmail.com','John','Smith']

# %%
df
# Out:
#                         email  first     last
# 0      coreyschafer@gmail.com  corey  schafer
# 1  victoriheanachoc@gmail.com   jane      doe
# 2         johnsmith@gmail.com   John    Smith

# %%
df.loc[2, ['last','email']] = ['Doe','johndoe@gmail.com']

# %%
df
# Out:
#                         email  first     last
# 0      coreyschafer@gmail.com  corey  schafer
# 1  victoriheanachoc@gmail.com   jane      doe
# 2           johndoe@gmail.com   John      Doe

# %%
df.at[1,'last'] = 'Andrew'

# %%
df
# Out:
#                         email  first     last
# 0      coreyschafer@gmail.com  corey  schafer
# 1  victoriheanachoc@gmail.com   jane   Andrew
# 2           johndoe@gmail.com   John      Doe

# %%
df['email'] = df['email'].str.lower()

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    26
# 2    17
# Name: email, dtype: int64

# %%
df['first'].map({'corey':'chris', 'jane':'Mary'})
# Out:
# 0    chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object
